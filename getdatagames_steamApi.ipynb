# %%
# standard library imports
import csv
import datetime as dt
import json
import os
import statistics
import time

# third-party imports
import numpy as np
import pandas as pd
import requests

# customisations - ensure tables show all columns
pd.set_option("display.max_columns", 100)

# %%
def get_request(url, parameters=None):
    """Return json-formatted response of a get request using optional parameters.
    
    Parameters
    ----------
    url : string
    parameters : {'parameter': 'value'}
        parameters to pass as part of get request
    
    Returns
    -------
    json_data
        json-formatted response (dict-like)
    """
    try:
        response = requests.get(url=url, params=parameters)
    except SSLError as s:
        print('SSL Error:', s)
        
        for i in range(30, 0, -1):
            print('\rWaiting... ({})'.format(i), end='')
            time.sleep(1)
        print('\rRetrying.' + ' '*10)
        
        # recusively try again
        return get_request(url, parameters)
    
    if response:
        return response.json()
    else:
        # response is none usually means too many requests. Wait and try again 
        print('No response, waiting 10 seconds...')
        time.sleep(50)
        print('Retrying.')
        return get_request(url, parameters)

# %%
url = "https://steamspy.com/api.php"
parameters = {"request": "all"}

# request 'all' from steam spy and parse into dataframe
json_data = get_request(url, parameters=parameters)
steam_spy_all = pd.DataFrame.from_dict(json_data, orient='index')

# generate sorted app_list from steamspy data
app_list = steam_spy_all[['appid', 'name']].sort_values('appid').reset_index(drop=True)

# export disabled to keep consistency across download sessions
# app_list.to_csv('../data/download/app_list.csv', index=False)

# instead read from stored csv
#app_list = pd.read_csv('../data/download/app_list.csv')

# display first few rows
app_list
# Out:
#        appid                                     name
# 0      33760            The Search for Amelia Earhart
# 1      34275                              Gain Ground
# 2      34277  Shinobi III: Return of the Ninja Master
# 3      34317                              Columns III
# 4      36900                          Angle of Attack
# ..       ...                                      ...
# 995  2196100                            Barren Depths
# 996  2196150                   Castle Defense Battles
# 997  2196370                              Cherry Lady
# 998  2196440                                     Gray
# 999  2197600                             Chess Royale
#
# [1000 rows x 2 columns]

# %%
def get_app_data(start, stop, parser, pause):
    """Return list of app data generated from parser.
    
    parser : function to handle request
    """
    app_data = []
    
    # iterate through each row of app_list, confined by start and stop
    for index, row in app_list[start:stop].iterrows():
        print('Current index: {}'.format(index), end='\r')
        
        appid = row['appid']
        name = row['name']

        # retrive app data for a row, handled by supplied parser, and append to list
        data = parser(appid, name)
        app_data.append(data)

        time.sleep(pause) # prevent overloading api with requests
    
    return app_data


def process_batches(parser, app_list, download_path, data_filename, index_filename,
                    columns, begin=0, end=-1, batchsize=100, pause=1):
    """Process app data in batches, writing directly to file.
    
    parser : custom function to format request
    app_list : dataframe of appid and name
    download_path : path to store data
    data_filename : filename to save app data
    index_filename : filename to store highest index written
    columns : column names for file
    
    Keyword arguments:
    
    begin : starting index (get from index_filename, default 0)
    end : index to finish (defaults to end of app_list)
    batchsize : number of apps to write in each batch (default 100)
    pause : time to wait after each api request (defualt 1)
    
    returns: none
    """
    print('Starting at index {}:\n'.format(begin))
    
    # by default, process all apps in app_list
    if end == -1:
        end = len(app_list) + 1
    
    # generate array of batch begin and end points
    batches = np.arange(begin, end, batchsize)
    batches = np.append(batches, end)
    
    apps_written = 0
    batch_times = []
    
    for i in range(len(batches) - 1):
        start_time = time.time()
        
        start = batches[i]
        stop = batches[i+1]
        
        app_data = get_app_data(start, stop, parser, pause)
        
        rel_path = os.path.join(download_path, data_filename)
        
        # writing app data to file
        with open(rel_path, 'a', newline='', encoding='utf-8') as f:
            writer = csv.DictWriter(f, fieldnames=columns, extrasaction='ignore')
            
            for j in range(3,0,-1):
                print("\rAbout to write data, don't stop script! ({})".format(j), end='')
                time.sleep(0.5)
            
            writer.writerows(app_data)
            print('\rExported lines {}-{} to {}.'.format(start, stop-1, data_filename), end=' ')
            
        apps_written += len(app_data)
        
        idx_path = os.path.join(download_path, index_filename)
        
        # writing last index to file
        with open(idx_path, 'w') as f:
            index = stop
            print(index, file=f)
            
        # logging time taken
        end_time = time.time()
        time_taken = end_time - start_time
        
        batch_times.append(time_taken)
        mean_time = statistics.mean(batch_times)
        
        est_remaining = (len(batches) - i - 2) * mean_time
        
        remaining_td = dt.timedelta(seconds=round(est_remaining))
        time_td = dt.timedelta(seconds=round(time_taken))
        mean_td = dt.timedelta(seconds=round(mean_time))
        
        print('Batch {} time: {} (avg: {}, remaining: {})'.format(i, time_td, mean_td, remaining_td))
            
    print('\nProcessing batches complete. {} apps written'.format(apps_written))

# %%
def reset_index(download_path, index_filename):
    """Reset index in file to 0."""
    rel_path = os.path.join(download_path, index_filename)
    
    with open(rel_path, 'w') as f:
        print(0, file=f)
        

def get_index(download_path, index_filename):
    """Retrieve index from file, returning 0 if file not found."""
    try:
        rel_path = os.path.join(download_path, index_filename)

        with open(rel_path, 'r') as f:
            index = int(f.readline())
    
    except FileNotFoundError:
        index = 0
        
    return index


def prepare_data_file(download_path, filename, index, columns):
    """Create file and write headers if index is 0."""
    if index == 0:
        rel_path = os.path.join(download_path, filename)

        with open(rel_path, 'w', newline='') as f:
            writer = csv.DictWriter(f, fieldnames=columns)
            writer.writeheader()

# %%
def parse_steam_request(appid, name):
    """Unique parser to handle data from Steam Store API.
    
    Returns : json formatted data (dict-like)
    """
    url = "http://store.steampowered.com/api/appdetails/"
    parameters = {"appids": appid}
    
    json_data = get_request(url, parameters=parameters)
    json_app_data = json_data[str(appid)]
    
    if json_app_data['success']:
        data = json_app_data['data']
    else:
        data = {'name': name, 'steam_appid': appid}
        
    return data


# Set file parameters
download_path = 'data'
steam_app_data = 'steam_app_data.csv'
steam_index = 'steam_index.txt'

steam_columns = [
    'type', 'name', 'steam_appid', 'required_age', 'is_free', 'controller_support',
    'dlc', 'detailed_description', 'about_the_game', 'short_description', 'fullgame',
    'supported_languages', 'header_image', 'website', 'pc_requirements', 'mac_requirements',
    'linux_requirements', 'legal_notice', 'drm_notice', 'ext_user_account_notice',
    'developers', 'publishers', 'demos', 'price_overview', 'packages', 'package_groups',
    'platforms', 'metacritic', 'reviews', 'categories', 'genres', 'screenshots',
    'movies', 'recommendations', 'achievements', 'release_date', 'support_info',
    'background', 'content_descriptors'
]

# Overwrites last index for demonstration (would usually store highest index so can continue across sessions)
reset_index(download_path, steam_index)

# Retrieve last index downloaded from file
index = get_index(download_path, steam_index)

# Wipe or create data file and write headers if index is 0
prepare_data_file(download_path, steam_app_data, index, steam_columns)

# Set end and chunksize for demonstration - remove to run through entire app list
process_batches(
    parser=parse_steam_request,
    app_list=app_list,
    download_path=download_path,
    data_filename=steam_app_data,
    index_filename=steam_index,
    columns=steam_columns,
    begin=index,
    end=30,
    batchsize=5
)
# Out:
# Starting at index 0:
#
# Exported lines 0-4 to steam_app_data.csv. Batch 0 time: 0:00:30 (avg: 0:00:30, remaining: 0:02:29)
# Exported lines 5-9 to steam_app_data.csv. Batch 1 time: 0:00:15 (avg: 0:00:22, remaining: 0:01:29)
# Exported lines 10-14 to steam_app_data.csv. Batch 2 time: 0:00:31 (avg: 0:00:25, remaining: 0:01:16)
# Exported lines 15-19 to steam_app_data.csv. Batch 3 time: 0:00:20 (avg: 0:00:24, remaining: 0:00:48)
# Exported lines 20-24 to steam_app_data.csv. Batch 4 time: 0:00:26 (avg: 0:00:24, remaining: 0:00:24)
# Exported lines 25-29 to steam_app_data.csv. Batch 5 time: 0:00:17 (avg: 0:00:23, remaining: 0:00:00)
#
# Processing batches complete. 30 apps written

# %%
# inspect downloaded data
pd.read_csv('data/steam_app_data.csv')
# Out:
#     type                                           name  steam_appid  \
# 0   game                  The Search for Amelia Earhart        33760
# 1   game                                   Gain Ground™        34275
# 2   game       Shinobi™ III: Return of the Ninja Master        34277
# 3   game                                   Columns™ III        34317
# 4   game                                Angle of Attack        36900
# 5   game                             All Aspect Warfare        36910
# 6   game   Hamilton's Great Adventure - Retro Fever DLC        42147
# 7   game                  Hearts of Iron III: Semper Fi        42900
# 8   game            ToeJam & Earl in Panic on Funkotron        71167
# 9   game                         The Revenge of Shinobi       211207
# 10  game                                    VectorMan 2       211208
# 11  game  Might & Magic: Heroes VI - Shades of Darkness       229790
# 12  game                                   Burning Cars       269430
# 13  game                                       Ohmicide       279280
# 14  game                 Galactic Command Echo Squad SE       285670
# 15  game                                   Bloonz Toonz       304190
# 16  game                        Frontline : Longest Day       312400
# 17  game                       Pacific Liberation Force       313190
# 18  game                           Vincere Totus Astrum       314610
# 19  game                                 Solar Struggle       330680
# 20  game                                      Soda Star       360720
# 21  game                 InsanZ - Retro Survival Horror       367040
# 22  game                        Retaliation: Enemy Mine       385810
# 23  game                         Get Rich or Die Gaming       395910
# 24  game                                Axes and Arrows       406400
# 25  game                                Inside The Code       431470
# 26  game                                      Emberdoom       476670
# 27  game                                           Taxi       488080
# 28  game                                     Endangered       500980
# 29  game                                   Gravity Shot       511960
#
#     required_age  is_free controller_support                    dlc  \
# 0              0    False                NaN                    NaN
# 1              0    False                NaN                    NaN
# 2              0    False                NaN                    NaN
# 3              0    False                NaN                    NaN
# 4              0    False                NaN                    NaN
# 5              0    False                NaN                    NaN
# 6              0    False                NaN                    NaN
# 7              0    False                NaN  [42905, 42903, 42902]
# 8              0    False                NaN                    NaN
# 9              0    False                NaN                    NaN
# 10             0    False                NaN                    NaN
# 11             0    False                NaN                    NaN
# 12             0    False               full                    NaN
# 13             0    False                NaN                    NaN
# 14             0    False                NaN                    NaN
# 15             0    False                NaN                    NaN
# 16             0    False                NaN                    NaN
# 17             0    False                NaN                    NaN
# 18             0    False                NaN                    NaN
# 19             0    False                NaN                    NaN
# 20             0    False                NaN                    NaN
# 21             0    False                NaN       [370230, 372170]
# 22             0    False                NaN                    NaN
# 23             0    False                NaN                    NaN
# 24             0    False               full                    NaN
# 25             0    False                NaN                    NaN
# 26             0    False                NaN                    NaN
# 27             0    False                NaN                    NaN
# 28             0     True                NaN                    NaN
# 29             0    False                NaN                    NaN
#
#                                  detailed_description  \
# 0   Follow Amelia Earhart’s life through space and...
# 1   The battle-simulation game has gone haywire!<b...
# 2   Joe Musashi’s sworn enemy, the Neo Zeed are se...
# 3   Arrange the blocks of jewels falling from the ...
# 4   The Terrans have been at war with the Gammulan...
# 5   An elite strike team — with a thermo-nuclear w...
# 6   This map pack contains new levels that bring b...
# 7   It’s time to dust off the field marshal's bato...
# 8   <h1>Just Updated</h1><p>All SEGA MegaDrive/Gen...
# 9   After being reduced to rubble by Joe Musashi, ...
# 10  A routine sludge barge excursion is cut short ...
# 11  A century after the tragic events of Might &am...
# 12  He got close a few times, but never won the Tr...
# 13  <h1>Audio Effect Plugins on Steam</h1><p>Ohmic...
# 14  Galactic Command Echo Squad SE is a high-end a...
# 15  Bloonz Toonz is an addictive and funny game fo...
# 16  June 6th, 1944. D-Day is the Allied operation ...
# 17  Are you ready to take up arms against El Presi...
# 18  &quot;Five empires have risen from the genetic...
# 19  Solar Struggle is an arcade action spaceshoote...
# 20  Can you manage a soda bottling plant gone hayw...
# 21  <strong>NOTE: THE GAME CONTAINS SCENES MAY BE ...
# 22  <strong>MULTIPLAYER MODE</strong><br><br>Retal...
# 23  A young man, Wilson Cooper, is playing video g...
# 24  <strong>Axes and Arrows</strong> is an intense...
# 25  Someone has sneaked in your house during the n...
# 26  The Ember has been banished from our realm for...
# 27  A sliding Tile puzzle game with 29 levels rang...
# 28  <h2 class="bb_tag">Single Player</h2><br>Plane...
# 29  Gravity Shot is an explosive physics based puz...
#
#                                        about_the_game  \
# 0   Follow Amelia Earhart’s life through space and...
# 1   The battle-simulation game has gone haywire!<b...
# 2   Joe Musashi’s sworn enemy, the Neo Zeed are se...
# 3   Arrange the blocks of jewels falling from the ...
# 4   The Terrans have been at war with the Gammulan...
# 5   An elite strike team — with a thermo-nuclear w...
# 6   This map pack contains new levels that bring b...
# 7   It’s time to dust off the field marshal's bato...
# 8   The peaceful planet of Funkotron has been inva...
# 9   After being reduced to rubble by Joe Musashi, ...
# 10  A routine sludge barge excursion is cut short ...
# 11  A century after the tragic events of Might &am...
# 12  He got close a few times, but never won the Tr...
# 13  Ohmicide:Melohman is an audio fx plugin which ...
# 14  Galactic Command Echo Squad SE is a high-end a...
# 15  Bloonz Toonz is an addictive and funny game fo...
# 16  June 6th, 1944. D-Day is the Allied operation ...
# 17  Are you ready to take up arms against El Presi...
# 18  &quot;Five empires have risen from the genetic...
# 19  Solar Struggle is an arcade action spaceshoote...
# 20  Can you manage a soda bottling plant gone hayw...
# 21  <strong>NOTE: THE GAME CONTAINS SCENES MAY BE ...
# 22  <strong>MULTIPLAYER MODE</strong><br><br>Retal...
# 23  A young man, Wilson Cooper, is playing video g...
# 24  <strong>Axes and Arrows</strong> is an intense...
# 25  Someone has sneaked in your house during the n...
# 26  The Ember has been banished from our realm for...
# 27  A sliding Tile puzzle game with 29 levels rang...
# 28  <h2 class="bb_tag">Single Player</h2><br>Plane...
# 29  Gravity Shot is an explosive physics based puz...
#
#                                     short_description  fullgame  \
# 0   Follow Amelia Earhart’s life through space and...       NaN
# 1   The battle-simulation game has gone haywire! A...       NaN
# 2   Joe Musashi’s sworn enemy, the Neo Zeed are se...       NaN
# 3   Arrange the blocks of jewels falling from the ...       NaN
# 4   Angle Of Attack is the aerial combat action co...       NaN
# 5   All Aspect Warfare is a thrilling planetary co...       NaN
# 6   This map pack contains new levels that bring b...       NaN
# 7   It’s time to dust off the field marshal's bato...       NaN
# 8   The peaceful planet of Funkotron has been inva...       NaN
# 9   After being reduced to rubble by Joe Musashi, ...       NaN
# 10  A routine sludge barge excursion is cut short ...       NaN
# 11  A century after the tragic events of Might &am...       NaN
# 12  He got close a few times, but never won the Tr...       NaN
# 13  A multi-band distortion audio effect available...       NaN
# 14  Galactic Command Echo Squad SE is a high-end a...       NaN
# 15  Bloonz Toonz is an addictive and funny game fo...       NaN
# 16  In Frontline: The Longest Day, players command...       NaN
# 17     Defeat El Presidente with an aerial onslaught!       NaN
# 18  Blending galaxy conquering with quick and easy...       NaN
# 19  Solar Struggle is an arcade space shooter with...       NaN
# 20  Soda Star is a competitive, single player puzz...       NaN
# 21  InsanZ is a retro-survival-horror-game of the ...       NaN
# 22  Retaliation: Enemy Mine offers challenging rea...       NaN
# 23                 Guide Wilson Cooper to his destiny       NaN
# 24  Axes and Arrows is an intense action-combat pl...       NaN
# 25  Inside The Code is a puzzle/action game. Fight...       NaN
# 26  Fight off the Ember invasion as they arrive in...       NaN
# 27  A sliding Tile puzzle game with 29 levels rang...       NaN
# 28  Aliens are invading Earth and are taking out E...       NaN
# 29  Sling shot explosive nuclear warheads into col...       NaN
#
#                                   supported_languages  \
# 0                                             English
# 1                                             English
# 2                                             English
# 3                                             English
# 4                                             English
# 5                                             English
# 6   English, French, Italian, German, Spanish - Sp...
# 7                                             English
# 8                                             English
# 9                                             English
# 10                                            English
# 11  Czech, English<strong>*</strong>, French<stron...
# 12                                   English, Russian
# 13                                            English
# 14  English<strong>*</strong><br><strong>*</strong...
# 15                                    English, German
# 16                                            English
# 17                                            English
# 18                                            English
# 19                                    English, German
# 20  English<strong>*</strong><br><strong>*</strong...
# 21  English<strong>*</strong><br><strong>*</strong...
# 22  English<strong>*</strong>, Italian, Simplified...
# 23  English<strong>*</strong><br><strong>*</strong...
# 24  English<strong>*</strong><br><strong>*</strong...
# 25  English<strong>*</strong><br><strong>*</strong...
# 26                                            English
# 27  English<strong>*</strong><br><strong>*</strong...
# 28  English<strong>*</strong><br><strong>*</strong...
# 29                                            English
#
#                                          header_image  \
# 0   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1   https://cdn.akamai.steamstatic.com/steam/apps/...
# 2   https://cdn.akamai.steamstatic.com/steam/apps/...
# 3   https://cdn.akamai.steamstatic.com/steam/apps/...
# 4   https://cdn.akamai.steamstatic.com/steam/apps/...
# 5   https://cdn.akamai.steamstatic.com/steam/apps/...
# 6   https://cdn.akamai.steamstatic.com/steam/apps/...
# 7   https://cdn.akamai.steamstatic.com/steam/apps/...
# 8   https://cdn.akamai.steamstatic.com/steam/apps/...
# 9   https://cdn.akamai.steamstatic.com/steam/apps/...
# 10  https://cdn.akamai.steamstatic.com/steam/apps/...
# 11  https://cdn.akamai.steamstatic.com/steam/apps/...
# 12  https://cdn.akamai.steamstatic.com/steam/apps/...
# 13  https://cdn.akamai.steamstatic.com/steam/apps/...
# 14  https://cdn.akamai.steamstatic.com/steam/apps/...
# 15  https://cdn.akamai.steamstatic.com/steam/apps/...
# 16  https://cdn.akamai.steamstatic.com/steam/apps/...
# 17  https://cdn.akamai.steamstatic.com/steam/apps/...
# 18  https://cdn.akamai.steamstatic.com/steam/apps/...
# 19  https://cdn.akamai.steamstatic.com/steam/apps/...
# 20  https://cdn.akamai.steamstatic.com/steam/apps/...
# 21  https://cdn.akamai.steamstatic.com/steam/apps/...
# 22  https://cdn.akamai.steamstatic.com/steam/apps/...
# 23  https://cdn.akamai.steamstatic.com/steam/apps/...
# 24  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25  https://cdn.akamai.steamstatic.com/steam/apps/...
# 26  https://cdn.akamai.steamstatic.com/steam/apps/...
# 27  https://cdn.akamai.steamstatic.com/steam/apps/...
# 28  https://cdn.akamai.steamstatic.com/steam/apps/...
# 29  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                               website  \
# 0                                                 NaN
# 1                                 http://www.sega.com
# 2                                 http://www.sega.com
# 3                                 http://www.sega.com
# 4            http://3000ad.com/games/angle-of-attack/
# 5         http://3000ad.com/games/all-aspect-warfare/
# 6                        http://hamilton.fatshark.se/
# 7                     http://www.heartsofirongame.com
# 8                                 http://www.sega.com
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                        http://www.bc.polynetix.com
# 13  https://www.ohmforce.com/ViewProduct.do?p=Ohmi...
# 14  http://3000ad.com/games/galcom-echo-squad-se-2...
# 15                                                NaN
# 16       http://slitherine.com/games/frontline_tld_pc
# 17                                                NaN
# 18                            http://www.gamesare.com
# 19                       http://www.solarstruggle.com
# 20             http://www.tinyutopia.com/?page_id=288
# 21                                                NaN
# 22                     http://www.retaliationgame.com
# 23                    https://dragonkingcreation.com/
# 24                       http://www.axesandarrows.com
# 25                                                NaN
# 26                                                NaN
# 27               https://petraguardsoftware.com/taxi/
# 28       https://endangered.strawberrygamestudios.com
# 29                                                NaN
#
#                                       pc_requirements  \
# 0   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 1   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 2   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 3   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 4   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 5   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 6   {'minimum': '<strong>Minimum:</strong><br><ul ...
# 7   {'minimum': '<ul class="bb_ul"><li><strong>OS:...
# 8   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 9   {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 10  {'minimum': '<strong>Minimum:</strong><br>\t\t...
# 11  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 12  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 13  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 14  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 17  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 18  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 19  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 20  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 23  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 24  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 26  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 27  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 28  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 29  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                      mac_requirements  \
# 0                                                  []
# 1   {'recommended': 'OS: OS Sierra Version 10.12.6...
# 2   {'recommended': 'OS: OS Sierra Version 10.12.6...
# 3   {'recommended': 'OS: OS Sierra Version 10.12.6...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8   {'recommended': 'OS: OS Sierra Version 10.12.6...
# 9   {'recommended': 'OS: OS Sierra Version 10.12.6...
# 10  {'recommended': 'OS: OS Sierra Version 10.12.6...
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21                                                 []
# 22  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 23                                                 []
# 24  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                                                 []
# 29  {'minimum': '<strong>Minimum:</strong><br><ul ...
#
#                                    linux_requirements  \
# 0                                                  []
# 1   {'recommended': 'OS: Ubuntu 16.10 or higher<br...
# 2   {'recommended': 'OS: Ubuntu 16.10 or higher<br...
# 3   {'recommended': 'OS: Ubuntu 16.10 or higher<br...
# 4                                                  []
# 5                                                  []
# 6                                                  []
# 7                                                  []
# 8   {'recommended': 'OS: Ubuntu 16.10 or higher<br...
# 9   {'recommended': 'OS: Ubuntu 16.10 or higher<br...
# 10  {'recommended': 'OS: Ubuntu 16.10 or higher<br...
# 11                                                 []
# 12                                                 []
# 13                                                 []
# 14  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 15                                                 []
# 16                                                 []
# 17                                                 []
# 18                                                 []
# 19                                                 []
# 20  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 21                                                 []
# 22                                                 []
# 23                                                 []
# 24  {'minimum': '<strong>Minimum:</strong><br><ul ...
# 25                                                 []
# 26                                                 []
# 27                                                 []
# 28                                                 []
# 29                                                 []
#
#                                          legal_notice  drm_notice  \
# 0                                                 NaN         NaN
# 1   Europe: © SEGA. SEGA, the SEGA logo and GAIN G...         NaN
# 2   Europe: © SEGA. SEGA, the SEGA logo and SHINOB...         NaN
# 3   Europe: © SEGA. SEGA, the SEGA logo and COLUMN...         NaN
# 4                Angle Of Attack  © 2009, 3000AD, Inc         NaN
# 5             All Aspect Warfare  © 2009, 3000AD, Inc         NaN
# 6             ©Fatshark AB. 2011 ALL RIGHTS RESERVED.         NaN
# 7   © 2009 Paradox Interactive AB. Hearts of Iron ...         NaN
# 8   Europe: © TOE JAM & EARL PRODUCTIONS, INC. © S...         NaN
# 9   © SEGA. All rights reserved. SEGA is registere...         NaN
# 10  © SEGA. All rights reserved. SEGA is registere...         NaN
# 11  © 2013 Ubisoft Entertainment. All Rights Reser...         NaN
# 12                                                NaN         NaN
# 13                         Copyright © 2014 Ohm Force         NaN
# 14                                                NaN         NaN
# 15                                                NaN         NaN
# 16  © 2014 Slitherine Ltd. and Matrix Games Ltd. A...         NaN
# 17                                                NaN         NaN
# 18                                                NaN         NaN
# 19                                                NaN         NaN
# 20                                                NaN         NaN
# 21                                                NaN         NaN
# 22                                                NaN         NaN
# 23                                                NaN         NaN
# 24                 Copyright 2015 The Net Champs LLC.         NaN
# 25                                                NaN         NaN
# 26                      Loud King Studios, LLC © 2017         NaN
# 27                                                NaN         NaN
# 28  Strawberry Game Studios, LLC, All Rights Reser...         NaN
# 29                                                NaN         NaN
#
#                       ext_user_account_notice  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
# 5                                         NaN
# 6                                         NaN
# 7                                         NaN
# 8                                         NaN
# 9                                         NaN
# 10                                        NaN
# 11  Uplay (Supports Linking to Steam Account)
# 12                                        NaN
# 13                                        NaN
# 14                                        NaN
# 15                                        NaN
# 16                                        NaN
# 17                                        NaN
# 18                                        NaN
# 19                                        NaN
# 20                                        NaN
# 21                                        NaN
# 22                                        NaN
# 23                                        NaN
# 24                                        NaN
# 25                                        NaN
# 26                                        NaN
# 27                                        NaN
# 28                                        NaN
# 29                                        NaN
#
#                               developers  \
# 0                            ['Bamtang']
# 1                               ['SEGA']
# 2                               ['SEGA']
# 3                               ['SEGA']
# 4                             ['3000AD']
# 5                             ['3000AD']
# 6                           ['Fatshark']
# 7         ['Paradox Development Studio']
# 8                               ['SEGA']
# 9                                    NaN
# 10                                   NaN
# 11                           ['Virtuos']
# 12                  ['Polynetix Studio']
# 13                         ['Ohm Force']
# 14                            ['3000AD']
# 15  ['United Independent Entertainment']
# 16                              ['88mm']
# 17                    ['Team 6 Studios']
# 18                          ['Gamesare']
# 19                        ['Z-Software']
# 20                       ['Tiny Utopia']
# 21                 ['SimplexGameStudio']
# 22     ['XTeam Software Solutions srls']
# 23                 ['Baller Industries']
# 24                    ['The Net Champs']
# 25                          ['Tinycorp']
# 26            ['Loud King Studios, LLC']
# 27            ['petraguardsoftware.com']
# 28      ['Strawberry Game Studios, LLC']
# 29                   ['Intrepid Marmot']
#
#                                            publishers  \
# 0                                  ['Cosmi Valusoft']
# 1                                            ['SEGA']
# 2                                            ['SEGA']
# 3                                            ['SEGA']
# 4                                          ['3000AD']
# 5                                          ['3000AD']
# 6                                        ['Fatshark']
# 7                             ['Paradox Interactive']
# 8                                            ['SEGA']
# 9                                            ['SEGA']
# 10                                           ['SEGA']
# 11                                        ['Ubisoft']
# 12                               ['Polynetix Studio']
# 13                                      ['Ohm Force']
# 14                                         ['3000AD']
# 15               ['United Independent Entertainment']
# 16                                ['Slitherine Ltd.']
# 17                                 ['Strategy First']
# 18                                      ['Clickteam']
# 19                                ['Z-Software GmbH']
# 20                                    ['Tiny Utopia']
# 21                              ['SimplexGameStudio']
# 22  ['Forgotten Empires LLC', 'XTeam Software Solu...
# 23                              ['Baller Industries']
# 24                                 ['The Net Champs']
# 25                                       ['Tinycorp']
# 26                         ['Loud King Studios, LLC']
# 27                         ['petraguardsoftware.com']
# 28                   ['Strawberry Game Studios, LLC']
# 29                                ['Intrepid Marmot']
#
#                                                 demos  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4               [{'appid': 36930, 'description': ''}]
# 5               [{'appid': 36920, 'description': ''}]
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14             [{'appid': 285690, 'description': ''}]
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22             [{'appid': 436700, 'description': ''}]
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28  [{'appid': 560610, 'description': 'Play Demo f...
# 29                                                NaN
#
#                                        price_overview        packages  \
# 0   {'currency': 'USD', 'initial': 699, 'final': 6...          [3009]
# 1   {'currency': 'USD', 'initial': 99, 'final': 99...          [4395]
# 2   {'currency': 'USD', 'initial': 99, 'final': 99...          [4397]
# 3   {'currency': 'USD', 'initial': 99, 'final': 99...          [6489]
# 4   {'currency': 'USD', 'initial': 999, 'final': 9...          [1939]
# 5   {'currency': 'USD', 'initial': 999, 'final': 9...          [1938]
# 6   {'currency': 'USD', 'initial': 99, 'final': 99...         [11813]
# 7   {'currency': 'USD', 'initial': 499, 'final': 4...          [4484]
# 8   {'currency': 'USD', 'initial': 99, 'final': 99...          [7093]
# 9   {'currency': 'USD', 'initial': 99, 'final': 99...         [14453]
# 10  {'currency': 'USD', 'initial': 99, 'final': 99...         [14454]
# 11  {'currency': 'USD', 'initial': 1499, 'final': ...  [19002, 27463]
# 12  {'currency': 'USD', 'initial': 599, 'final': 5...         [35737]
# 13  {'currency': 'USD', 'initial': 12499, 'final':...         [38218]
# 14  {'currency': 'USD', 'initial': 999, 'final': 9...         [39603]
# 15  {'currency': 'USD', 'initial': 299, 'final': 2...         [44964]
# 16  {'currency': 'USD', 'initial': 499, 'final': 4...         [47085]
# 17  {'currency': 'USD', 'initial': 499, 'final': 4...         [47299]
# 18  {'currency': 'USD', 'initial': 399, 'final': 3...         [47815]
# 19  {'currency': 'USD', 'initial': 599, 'final': 5...         [53594]
# 20  {'currency': 'USD', 'initial': 399, 'final': 3...         [64475]
# 21  {'currency': 'USD', 'initial': 699, 'final': 6...         [66462]
# 22  {'currency': 'USD', 'initial': 499, 'final': 4...         [72773]
# 23  {'currency': 'USD', 'initial': 299, 'final': 2...         [76140]
# 24  {'currency': 'USD', 'initial': 299, 'final': 2...         [80507]
# 25  {'currency': 'USD', 'initial': 399, 'final': 3...         [89646]
# 26  {'currency': 'USD', 'initial': 999, 'final': 9...        [106147]
# 27  {'currency': 'USD', 'initial': 199, 'final': 1...        [110030]
# 28                                                NaN        [419701]
# 29  {'currency': 'USD', 'initial': 699, 'final': 6...        [119094]
#
#                                        package_groups  \
# 0   [{'name': 'default', 'title': 'Buy The Search ...
# 1   [{'name': 'default', 'title': 'Buy Gain Ground...
# 2   [{'name': 'default', 'title': 'Buy Shinobi™ II...
# 3   [{'name': 'default', 'title': 'Buy Columns™ II...
# 4   [{'name': 'default', 'title': 'Buy Angle of At...
# 5   [{'name': 'default', 'title': 'Buy All Aspect ...
# 6   [{'name': 'default', 'title': "Buy Hamilton's ...
# 7   [{'name': 'default', 'title': 'Buy Hearts of I...
# 8   [{'name': 'default', 'title': 'Buy ToeJam & Ea...
# 9   [{'name': 'default', 'title': 'Buy The Revenge...
# 10  [{'name': 'default', 'title': 'Buy VectorMan 2...
# 11  [{'name': 'default', 'title': 'Buy Might & Mag...
# 12  [{'name': 'default', 'title': 'Buy Burning Car...
# 13  [{'name': 'default', 'title': 'Buy Ohmicide', ...
# 14  [{'name': 'default', 'title': 'Buy Galactic Co...
# 15  [{'name': 'default', 'title': 'Buy Bloonz Toon...
# 16  [{'name': 'default', 'title': 'Buy Frontline :...
# 17  [{'name': 'default', 'title': 'Buy Pacific Lib...
# 18  [{'name': 'default', 'title': 'Buy Vincere Tot...
# 19  [{'name': 'default', 'title': 'Buy Solar Strug...
# 20  [{'name': 'default', 'title': 'Buy Soda Star',...
# 21  [{'name': 'default', 'title': 'Buy InsanZ - Re...
# 22  [{'name': 'default', 'title': 'Buy Retaliation...
# 23  [{'name': 'default', 'title': 'Buy Get Rich or...
# 24  [{'name': 'default', 'title': 'Buy Axes and Ar...
# 25  [{'name': 'default', 'title': 'Buy Inside The ...
# 26  [{'name': 'default', 'title': 'Buy Emberdoom',...
# 27  [{'name': 'default', 'title': 'Buy Taxi', 'des...
# 28  [{'name': 'default', 'title': 'Buy Endangered'...
# 29  [{'name': 'default', 'title': 'Buy Gravity Sho...
#
#                                           platforms  \
# 0   {'windows': True, 'mac': False, 'linux': False}
# 1     {'windows': True, 'mac': True, 'linux': True}
# 2     {'windows': True, 'mac': True, 'linux': True}
# 3     {'windows': True, 'mac': True, 'linux': True}
# 4   {'windows': True, 'mac': False, 'linux': False}
# 5   {'windows': True, 'mac': False, 'linux': False}
# 6   {'windows': True, 'mac': False, 'linux': False}
# 7   {'windows': True, 'mac': False, 'linux': False}
# 8     {'windows': True, 'mac': True, 'linux': True}
# 9     {'windows': True, 'mac': True, 'linux': True}
# 10    {'windows': True, 'mac': True, 'linux': True}
# 11  {'windows': True, 'mac': False, 'linux': False}
# 12  {'windows': True, 'mac': False, 'linux': False}
# 13  {'windows': True, 'mac': False, 'linux': False}
# 14  {'windows': True, 'mac': False, 'linux': False}
# 15   {'windows': True, 'mac': True, 'linux': False}
# 16  {'windows': True, 'mac': False, 'linux': False}
# 17  {'windows': True, 'mac': False, 'linux': False}
# 18  {'windows': True, 'mac': False, 'linux': False}
# 19  {'windows': True, 'mac': False, 'linux': False}
# 20    {'windows': True, 'mac': True, 'linux': True}
# 21  {'windows': True, 'mac': False, 'linux': False}
# 22   {'windows': True, 'mac': True, 'linux': False}
# 23  {'windows': True, 'mac': False, 'linux': False}
# 24  {'windows': True, 'mac': False, 'linux': False}
# 25  {'windows': True, 'mac': False, 'linux': False}
# 26  {'windows': True, 'mac': False, 'linux': False}
# 27  {'windows': True, 'mac': False, 'linux': False}
# 28  {'windows': True, 'mac': False, 'linux': False}
# 29   {'windows': True, 'mac': True, 'linux': False}
#
#                                            metacritic  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7   {'score': 65, 'url': 'https://www.metacritic.c...
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13                                                NaN
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                               reviews  \
# 0   “The Search for Amelia Earhart offers a fun wa...
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4   &quot;Those who enjoy flight simulations but n...
# 5   &quot;It's a welcome change from shooters-on-r...
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12                                                NaN
# 13  “It's an absolutely crazy multiband distortion...
# 14                                                NaN
# 15                                                NaN
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19                                                NaN
# 20                                                NaN
# 21                                                NaN
# 22  “this game has all that was missing - and sore...
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27                                                NaN
# 28                                                NaN
# 29                                                NaN
#
#                                            categories  \
# 0         [{'id': 2, 'description': 'Single-player'}]
# 1   [{'id': 2, 'description': 'Single-player'}, {'...
# 2   [{'id': 2, 'description': 'Single-player'}, {'...
# 3   [{'id': 2, 'description': 'Single-player'}, {'...
# 4   [{'id': 2, 'description': 'Single-player'}, {'...
# 5   [{'id': 2, 'description': 'Single-player'}, {'...
# 6   [{'id': 2, 'description': 'Single-player'}, {'...
# 7   [{'id': 1, 'description': 'Multi-player'}, {'i...
# 8   [{'id': 2, 'description': 'Single-player'}, {'...
# 9         [{'id': 2, 'description': 'Single-player'}]
# 10        [{'id': 2, 'description': 'Single-player'}]
# 11  [{'id': 2, 'description': 'Single-player'}, {'...
# 12  [{'id': 2, 'description': 'Single-player'}, {'...
# 13                                                NaN
# 14  [{'id': 2, 'description': 'Single-player'}, {'...
# 15  [{'id': 2, 'description': 'Single-player'}, {'...
# 16        [{'id': 2, 'description': 'Single-player'}]
# 17        [{'id': 2, 'description': 'Single-player'}]
# 18        [{'id': 2, 'description': 'Single-player'}]
# 19  [{'id': 2, 'description': 'Single-player'}, {'...
# 20        [{'id': 2, 'description': 'Single-player'}]
# 21        [{'id': 2, 'description': 'Single-player'}]
# 22  [{'id': 2, 'description': 'Single-player'}, {'...
# 23        [{'id': 2, 'description': 'Single-player'}]
# 24  [{'id': 2, 'description': 'Single-player'}, {'...
# 25        [{'id': 2, 'description': 'Single-player'}]
# 26  [{'id': 2, 'description': 'Single-player'}, {'...
# 27  [{'id': 2, 'description': 'Single-player'}, {'...
# 28  [{'id': 2, 'description': 'Single-player'}, {'...
# 29  [{'id': 2, 'description': 'Single-player'}, {'...
#
#                                                genres  \
# 0              [{'id': '4', 'description': 'Casual'}]
# 1            [{'id': '2', 'description': 'Strategy'}]
# 2              [{'id': '1', 'description': 'Action'}]
# 3              [{'id': '4', 'description': 'Casual'}]
# 4   [{'id': '1', 'description': 'Action'}, {'id': ...
# 5   [{'id': '1', 'description': 'Action'}, {'id': ...
# 6   [{'id': '25', 'description': 'Adventure'}, {'i...
# 7            [{'id': '2', 'description': 'Strategy'}]
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11  [{'id': '3', 'description': 'RPG'}, {'id': '2'...
# 12             [{'id': '9', 'description': 'Racing'}]
# 13  [{'id': '52', 'description': 'Audio Production'}]
# 14  [{'id': '1', 'description': 'Action'}, {'id': ...
# 15             [{'id': '4', 'description': 'Casual'}]
# 16           [{'id': '2', 'description': 'Strategy'}]
# 17             [{'id': '4', 'description': 'Casual'}]
# 18           [{'id': '2', 'description': 'Strategy'}]
# 19  [{'id': '1', 'description': 'Action'}, {'id': ...
# 20  [{'id': '4', 'description': 'Casual'}, {'id': ...
# 21  [{'id': '1', 'description': 'Action'}, {'id': ...
# 22           [{'id': '2', 'description': 'Strategy'}]
# 23         [{'id': '25', 'description': 'Adventure'}]
# 24  [{'id': '1', 'description': 'Action'}, {'id': ...
# 25  [{'id': '25', 'description': 'Adventure'}, {'i...
# 26  [{'id': '1', 'description': 'Action'}, {'id': ...
# 27             [{'id': '4', 'description': 'Casual'}]
# 28  [{'id': '1', 'description': 'Action'}, {'id': ...
# 29  [{'id': '4', 'description': 'Casual'}, {'id': ...
#
#                                           screenshots  \
# 0   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 1   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 2   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 3   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 4   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 5   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 6   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 7   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 8   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 9   [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 10  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 11  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 12  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 13  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 14  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 15  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 16  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 17  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 18  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 19  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 20  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 21  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 22  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 23  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 24  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 25  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 26  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 27  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 28  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
# 29  [{'id': 0, 'path_thumbnail': 'https://cdn.akam...
#
#                                                movies  recommendations  \
# 0                                                 NaN              NaN
# 1   [{'id': 256663650, 'name': 'SMDC PEGI', 'thumb...              NaN
# 2   [{'id': 256663652, 'name': 'SMDC ESRB', 'thumb...              NaN
# 3                                                 NaN              NaN
# 4   [{'id': 2031371, 'name': 'Air Combat', 'thumbn...              NaN
# 5   [{'id': 900984, 'name': 'Gameplay Tutorial 1',...              NaN
# 6                                                 NaN              NaN
# 7                                                 NaN              NaN
# 8                                                 NaN              NaN
# 9                                                 NaN              NaN
# 10                                                NaN              NaN
# 11  [{'id': 2028651, 'name': 'Might and Magic Hero...              NaN
# 12  [{'id': 2030797, 'name': 'Burning Cars', 'thum...              NaN
# 13  [{'id': 2033607, 'name': 'Ohmicide Trailer', '...              NaN
# 14  [{'id': 2031367, 'name': 'Space Combat Movie 0...              NaN
# 15  [{'id': 256661562, 'name': 'Gameplay', 'thumbn...              NaN
# 16  [{'id': 2035871, 'name': 'Frontline: The Longe...              NaN
# 17  [{'id': 2034242, 'name': 'Gameplay Trailer', '...              NaN
# 18  [{'id': 2033572, 'name': 'Vincere Totus Astrum...              NaN
# 19  [{'id': 2035336, 'name': 'Solar Struggle - Tra...              NaN
# 20  [{'id': 2038588, 'name': 'Soda Star Launch Tra...              NaN
# 21  [{'id': 2038858, 'name': 'Gameplay', 'thumbnai...              NaN
# 22  [{'id': 256656036, 'name': 'Retaliation Enemy ...              NaN
# 23  [{'id': 256656100, 'name': 'GRODG Trailer', 't...              NaN
# 24  [{'id': 256657050, 'name': 'Axes and Arrows Al...              NaN
# 25  [{'id': 256659549, 'name': 'Inside The Code - ...              NaN
# 26  [{'id': 256674677, 'name': 'Emberdoom', 'thumb...              NaN
# 27  [{'id': 256670791, 'name': 'Taxi Gameplay', 't...              NaN
# 28  [{'id': 256719785, 'name': 'Endangered', 'thum...              NaN
# 29  [{'id': 256672652, 'name': 'Trailer1', 'thumbn...              NaN
#
#                                          achievements  \
# 0                                                 NaN
# 1                                                 NaN
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5                                                 NaN
# 6                                                 NaN
# 7                                                 NaN
# 8                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 11                                                NaN
# 12  {'total': 15, 'highlighted': [{'name': 'Winner...
# 13                                                NaN
# 14                                                NaN
# 15                                       {'total': 0}
# 16                                                NaN
# 17                                                NaN
# 18                                                NaN
# 19  {'total': 37, 'highlighted': [{'name': 'The be...
# 20                                                NaN
# 21                                                NaN
# 22                                                NaN
# 23                                                NaN
# 24                                                NaN
# 25                                                NaN
# 26                                                NaN
# 27  {'total': 11, 'highlighted': [{'name': 'On a R...
# 28                                                NaN
# 29                                                NaN
#
#                                       release_date  \
# 0   {'coming_soon': False, 'date': '22 Feb, 2010'}
# 1    {'coming_soon': False, 'date': '1 Jun, 2010'}
# 2    {'coming_soon': False, 'date': '1 Jun, 2010'}
# 3   {'coming_soon': False, 'date': '26 Oct, 2010'}
# 4   {'coming_soon': False, 'date': '17 Aug, 2009'}
# 5   {'coming_soon': False, 'date': '17 Aug, 2009'}
# 6    {'coming_soon': False, 'date': '3 Oct, 2011'}
# 7    {'coming_soon': False, 'date': '7 Jun, 2010'}
# 8   {'coming_soon': False, 'date': '14 Mar, 2012'}
# 9    {'coming_soon': False, 'date': '2 May, 2012'}
# 10   {'coming_soon': False, 'date': '2 May, 2012'}
# 11   {'coming_soon': False, 'date': '2 May, 2013'}
# 12  {'coming_soon': False, 'date': '31 Jan, 2014'}
# 13  {'coming_soon': False, 'date': '23 Jul, 2014'}
# 14  {'coming_soon': False, 'date': '10 Mar, 2014'}
# 15  {'coming_soon': False, 'date': '11 Mar, 2016'}
# 16   {'coming_soon': False, 'date': '9 Dec, 2014'}
# 17  {'coming_soon': False, 'date': '16 Sep, 2014'}
# 18  {'coming_soon': False, 'date': '20 Feb, 2017'}
# 19  {'coming_soon': False, 'date': '18 Nov, 2014'}
# 20  {'coming_soon': False, 'date': '14 May, 2015'}
# 21  {'coming_soon': False, 'date': '27 Apr, 2015'}
# 22  {'coming_soon': False, 'date': '22 Jan, 2016'}
# 23   {'coming_soon': False, 'date': '2 Sep, 2015'}
# 24   {'coming_soon': False, 'date': '8 Oct, 2015'}
# 25   {'coming_soon': False, 'date': '8 Jan, 2016'}
# 26  {'coming_soon': False, 'date': '26 Sep, 2017'}
# 27   {'coming_soon': False, 'date': '7 Oct, 2016'}
# 28  {'coming_soon': False, 'date': '10 Jan, 2019'}
# 29   {'coming_soon': False, 'date': '9 Nov, 2016'}
#
#                                          support_info  \
# 0                            {'url': '', 'email': ''}
# 1   {'url': 'https://support.sega.co.uk', 'email':...
# 2   {'url': 'https://support.sega.co.uk', 'email':...
# 3   {'url': 'https://support.sega.co.uk', 'email':...
# 4   {'url': 'http://3000ad.com/support/', 'email':...
# 5   {'url': 'http://3000ad.com/support/', 'email':...
# 6                            {'url': '', 'email': ''}
# 7                            {'url': '', 'email': ''}
# 8   {'url': 'https://support.sega.co.uk', 'email':...
# 9   {'url': 'https://support.sega.co.uk', 'email':...
# 10  {'url': 'https://support.sega.co.uk', 'email':...
# 11                           {'url': '', 'email': ''}
# 12  {'url': 'http://www.polynetix.com/cgi-bin/yabb...
# 13  {'url': 'https://www.ohmforce.com/Support.do',...
# 14  {'url': 'http://3000ad.com/support/', 'email':...
# 15            {'url': '', 'email': 'support@uieg.de'}
# 16  {'url': 'http://slitherine.com/forum/viewforum...
# 17  {'url': '', 'email': 'support@strategyfirst.com'}
# 18  {'url': 'http://www.Clickteam.com', 'email': '...
# 19     {'url': '', 'email': 'contact@z-software.net'}
# 20  {'url': 'http://www.tinyutopia.com/', 'email':...
# 21  {'url': 'https://support.steampowered.com/', '...
# 22  {'url': 'http://www.retaliationgame.com', 'ema...
# 23  {'url': 'https://dragonkingcreation.com/', 'em...
# 24  {'url': 'http://www.axesandarrows.com', 'email...
# 25        {'url': '', 'email': 'cp080194@hotmail.it'}
# 26  {'url': 'https://www.loudkingstudios.com', 'em...
# 27  {'url': 'https://petraguardsoftware.com/contac...
# 28  {'url': 'http://strawberrygamestudios.com', 'e...
# 29                           {'url': '', 'email': ''}
#
#                                            background  \
# 0   https://cdn.akamai.steamstatic.com/steam/apps/...
# 1   https://cdn.akamai.steamstatic.com/steam/apps/...
# 2   https://cdn.akamai.steamstatic.com/steam/apps/...
# 3   https://cdn.akamai.steamstatic.com/steam/apps/...
# 4   https://cdn.akamai.steamstatic.com/steam/apps/...
# 5   https://cdn.akamai.steamstatic.com/steam/apps/...
# 6   https://cdn.akamai.steamstatic.com/steam/apps/...
# 7   https://cdn.akamai.steamstatic.com/steam/apps/...
# 8   https://cdn.akamai.steamstatic.com/steam/apps/...
# 9   https://cdn.akamai.steamstatic.com/steam/apps/...
# 10  https://cdn.akamai.steamstatic.com/steam/apps/...
# 11  https://cdn.akamai.steamstatic.com/steam/apps/...
# 12  https://cdn.akamai.steamstatic.com/steam/apps/...
# 13  https://cdn.akamai.steamstatic.com/steam/apps/...
# 14  https://cdn.akamai.steamstatic.com/steam/apps/...
# 15  https://cdn.akamai.steamstatic.com/steam/apps/...
# 16  https://cdn.akamai.steamstatic.com/steam/apps/...
# 17  https://cdn.akamai.steamstatic.com/steam/apps/...
# 18  https://cdn.akamai.steamstatic.com/steam/apps/...
# 19  https://cdn.akamai.steamstatic.com/steam/apps/...
# 20  https://cdn.akamai.steamstatic.com/steam/apps/...
# 21  https://cdn.akamai.steamstatic.com/steam/apps/...
# 22  https://cdn.akamai.steamstatic.com/steam/apps/...
# 23  https://cdn.akamai.steamstatic.com/steam/apps/...
# 24  https://cdn.akamai.steamstatic.com/steam/apps/...
# 25  https://cdn.akamai.steamstatic.com/steam/apps/...
# 26  https://cdn.akamai.steamstatic.com/steam/apps/...
# 27  https://cdn.akamai.steamstatic.com/steam/apps/...
# 28  https://cdn.akamai.steamstatic.com/steam/apps/...
# 29  https://cdn.akamai.steamstatic.com/steam/apps/...
#
#                                content_descriptors
# 0                       {'ids': [], 'notes': None}
# 1                       {'ids': [], 'notes': None}
# 2                       {'ids': [], 'notes': None}
# 3                       {'ids': [], 'notes': None}
# 4                       {'ids': [], 'notes': None}
# 5                       {'ids': [], 'notes': None}
# 6                       {'ids': [], 'notes': None}
# 7                       {'ids': [], 'notes': None}
# 8                       {'ids': [], 'notes': None}
# 9                       {'ids': [], 'notes': None}
# 10                      {'ids': [], 'notes': None}
# 11                      {'ids': [], 'notes': None}
# 12                      {'ids': [], 'notes': None}
# 13                      {'ids': [], 'notes': None}
# 14                      {'ids': [], 'notes': None}
# 15                      {'ids': [], 'notes': None}
# 16                      {'ids': [], 'notes': None}
# 17                      {'ids': [], 'notes': None}
# 18                      {'ids': [], 'notes': None}
# 19                      {'ids': [], 'notes': None}
# 20                      {'ids': [], 'notes': None}
# 21                     {'ids': [5], 'notes': None}
# 22                      {'ids': [], 'notes': None}
# 23                      {'ids': [], 'notes': None}
# 24                      {'ids': [], 'notes': None}
# 25                      {'ids': [], 'notes': None}
# 26                      {'ids': [], 'notes': None}
# 27                      {'ids': [], 'notes': None}
# 28  {'ids': [2, 5], 'notes': 'Moderate Violence.'}
# 29                      {'ids': [], 'notes': None}
